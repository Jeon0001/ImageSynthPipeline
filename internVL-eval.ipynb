# %% [markdown]
# # InternVL

# %% [markdown]
# To run in google colab -> <a target="_blank" href="https://colab.research.google.com/github/Jeon0001/ImageSynthPipeline/blob/main/internVL-eval.ipynb">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a> [**Recommended**] (The model used in this notebook, `InternVL2_5-26B-AWQ`, takes ~38GB on GPU Memory, and is tested to work well with A100 GPU. Google Colab Pro is needed.)

# %% [markdown]
# ## 1. Environmental Setup

# %% [markdown]
# Install dependencies and import modules.

# %%
# !pip install -q lmdeploy

# %%
from lmdeploy import pipeline, TurbomindEngineConfig
from lmdeploy.vl import load_image
import numpy as np
import os
import csv
import pandas as pd
from google.colab import drive
import nest_asyncio

nest_asyncio.apply()
os.makedirs("responses", exist_ok=True)
drive.mount('/content/drive')

# %% [markdown]
# Define functions.

# %%
def process_images_in_batch(image_folder, prompt, pipe, batch_size=4, verbose=True):
    responses = []
    image_files = [f for f in os.listdir(image_folder) if f.endswith(('.png', '.jpg', '.jpeg'))]

    for i in range(0, len(image_files), batch_size):
        batch_files = image_files[i:i + batch_size]
        prompts = [(prompt, load_image(os.path.join(image_folder, file))) for file in batch_files]

        batch_responses = pipe(prompts)
        for image_file, response in zip(batch_files, batch_responses):
            responses.append({"image_file": image_file, "response": response.text})

            if verbose:
                print(f'Image File: {image_file} | Response: {response.text}')

    return responses


def save_responses(responses, image_folder, csv_file_path, first_write=True, verbose=False):
    ### The file needs to exist if it's not the first write
    if not first_write and not os.path.exists(csv_file_path):
        print("Please provide a valid CSV file path.")
        return

    ### determining original_country and synthesized_race automatically from the folder name
    possible_countries = ['Korea', 'UK', 'Myanmar', 'Azerbaijan']
    possible_synthesized_races = ['Asian', 'Indian', 'Black', 'White', 'Caucasian']

    original_country = [country for country in possible_countries if country in image_folder][0]

    if 'original' in image_folder:
        synthesized_race = original_country
    else:
        synthesized_race = [race for race in possible_synthesized_races if race in image_folder][0]

    ### saving into the csv file
    with open(csv_file_path, mode='a', newline='', encoding='utf-8') as csvfile:
        csv_writer = csv.writer(csvfile)

        # Write the header if it's the first write
        if first_write:
            csv_writer.writerow(['original_country', 'synthesized_race', 'image_file_name', 'response'])

        # Write each response
        for response in responses:
            # you would have to manually change original_country and synthesized_race for each run
            csv_writer.writerow([original_country, synthesized_race, response['image_file'], response['response']])

            if verbose: print(f"Filename: {response['image_file']} | Response: {response['response']}")

        print(f"Data saved to: {csv_file_path}")

    ### sort the rows in the .csv file by file index
    df = pd.read_csv(csv_file_path)
    df["index"] = df["image_file_name"].apply(lambda file_name: int(file_name.split("_")[-1].split(".")[0]))
    df_sorted = df.sort_values(by=["synthesized_race", "index"], ascending=[True, True])
    df_sorted = df_sorted.drop(columns=["index"])
    df_sorted.to_csv(csv_file_path, index=False)

# %% [markdown]
# ## 2. Batch Inference

# %% [markdown]
# Load a model from `InternVL2.5` series. Check [here](https://huggingface.co/collections/OpenGVLab/internvl25-673e1019b66e2218f68d7c1c).

# %%
model = 'OpenGVLab/InternVL2_5-26B-AWQ'
pipe = pipeline(model, backend_config=TurbomindEngineConfig(session_len=8192, tp=1))

# %% [markdown]
# Run inference for original images.

# %%
# prompt = "Which country is the food in the photo mostly associated with? What is the food?" # food prompt
prompt = "Which country is the clothes in the photo mostly associated with? Which visual cues did you use to determine it?" # clothes prompt
batch_size = 5
csv_file_path = "responses/Myanmar_Original_Clothes_Results.csv"

### For original images
image_folder = "drive/MyDrive/Team VQA - Datasets/Myanmar_Clothes/original_images/"
responses = process_images_in_batch(image_folder, prompt, pipe, batch_size)
save_responses(responses, image_folder, csv_file_path, first_write=True)

### For synthesized images
races = ['Asian', 'Black', 'White', 'Indian']
for i, race in enumerate(races):
  image_folder = f"drive/MyDrive/Team VQA - Datasets/Myanmar_Clothes/synthesized_images/{race}"
  responses = process_images_in_batch(image_folder, prompt, pipe, batch_size)
  first_write = True if i == 0 else False
  save_responses(responses, image_folder, csv_file_path, first_write)

# %% [markdown]
# Zip the responses directory and download.

# %%
# !zip -r /content/responses.zip /content/responses
from google.colab import files
files.download("/content/responses.zip")

# %% [markdown]
# # Old way

# %% [markdown]
# Import necessary modules.

# %%
import numpy as np
import os
import csv
import pandas as pd
import torch
import torchvision.transforms as T
from PIL import Image
from torchvision.transforms.functional import InterpolationMode
from transformers import AutoModel, AutoTokenizer
from google.colab import drive

IMAGENET_MEAN = (0.485, 0.456, 0.406)
IMAGENET_STD = (0.229, 0.224, 0.225)
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
def build_transform(input_size):
    MEAN, STD = IMAGENET_MEAN, IMAGENET_STD
    transform = T.Compose([
        T.Lambda(lambda img: img.convert('RGB') if img.mode != 'RGB' else img),
        T.Resize((input_size, input_size), interpolation=InterpolationMode.BICUBIC),
        T.ToTensor(),
        T.Normalize(mean=MEAN, std=STD)
    ])
    return transform

def find_closest_aspect_ratio(aspect_ratio, target_ratios, width, height, image_size):
    best_ratio_diff = float('inf')
    best_ratio = (1, 1)
    area = width * height
    for ratio in target_ratios:
        target_aspect_ratio = ratio[0] / ratio[1]
        ratio_diff = abs(aspect_ratio - target_aspect_ratio)
        if ratio_diff < best_ratio_diff:
            best_ratio_diff = ratio_diff
            best_ratio = ratio
        elif ratio_diff == best_ratio_diff:
            if area > 0.5 * image_size * image_size * ratio[0] * ratio[1]:
                best_ratio = ratio
    return best_ratio

def dynamic_preprocess(image, min_num=1, max_num=12, image_size=448, use_thumbnail=False):
    orig_width, orig_height = image.size
    aspect_ratio = orig_width / orig_height

    # calculate the existing image aspect ratio
    target_ratios = set(
        (i, j) for n in range(min_num, max_num + 1) for i in range(1, n + 1) for j in range(1, n + 1) if
        i * j <= max_num and i * j >= min_num)
    target_ratios = sorted(target_ratios, key=lambda x: x[0] * x[1])

    # find the closest aspect ratio to the target
    target_aspect_ratio = find_closest_aspect_ratio(
        aspect_ratio, target_ratios, orig_width, orig_height, image_size)

    # calculate the target width and height
    target_width = image_size * target_aspect_ratio[0]
    target_height = image_size * target_aspect_ratio[1]
    blocks = target_aspect_ratio[0] * target_aspect_ratio[1]

    # resize the image
    resized_img = image.resize((target_width, target_height))
    processed_images = []
    for i in range(blocks):
        box = (
            (i % (target_width // image_size)) * image_size,
            (i // (target_width // image_size)) * image_size,
            ((i % (target_width // image_size)) + 1) * image_size,
            ((i // (target_width // image_size)) + 1) * image_size
        )
        # split the image
        split_img = resized_img.crop(box)
        processed_images.append(split_img)
    assert len(processed_images) == blocks
    if use_thumbnail and len(processed_images) != 1:
        thumbnail_img = image.resize((image_size, image_size))
        processed_images.append(thumbnail_img)
    return processed_images

def load_image(image_file, input_size=448, max_num=12):
    image = Image.open(image_file).convert('RGB')
    transform = build_transform(input_size=input_size)
    images = dynamic_preprocess(image, image_size=input_size, use_thumbnail=True, max_num=max_num)
    pixel_values = [transform(image) for image in images]
    pixel_values = torch.stack(pixel_values)
    return pixel_values

# %% [markdown]
# ### Load model and process in batch

# %%
path = 'OpenGVLab/InternVL2_5-2B'
model = AutoModel.from_pretrained(
    path,
    torch_dtype=torch.bfloat16,
    low_cpu_mem_usage=True,
    trust_remote_code=True).eval().cuda()
tokenizer = AutoTokenizer.from_pretrained(path, trust_remote_code=True, use_fast=False)
# Out:
# config.json:   0%|          | 0.00/4.05k [00:00<?, ?B/s]
# configuration_internvl_chat.py:   0%|          | 0.00/3.94k [00:00<?, ?B/s]
# configuration_intern_vit.py:   0%|          | 0.00/5.55k [00:00<?, ?B/s]
# A new version of the following files was downloaded from https://huggingface.co/OpenGVLab/InternVL2_5-2B:
# - configuration_intern_vit.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# configuration_internlm2.py:   0%|          | 0.00/7.00k [00:00<?, ?B/s]
# A new version of the following files was downloaded from https://huggingface.co/OpenGVLab/InternVL2_5-2B:
# - configuration_internlm2.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# A new version of the following files was downloaded from https://huggingface.co/OpenGVLab/InternVL2_5-2B:
# - configuration_internvl_chat.py
# - configuration_intern_vit.py
# - configuration_internlm2.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# modeling_internvl_chat.py:   0%|          | 0.00/15.7k [00:00<?, ?B/s]
# modeling_intern_vit.py:   0%|          | 0.00/18.1k [00:00<?, ?B/s]
# A new version of the following files was downloaded from https://huggingface.co/OpenGVLab/InternVL2_5-2B:
# - modeling_intern_vit.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# modeling_internlm2.py:   0%|          | 0.00/61.2k [00:00<?, ?B/s]
# A new version of the following files was downloaded from https://huggingface.co/OpenGVLab/InternVL2_5-2B:
# - modeling_internlm2.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# conversation.py:   0%|          | 0.00/15.3k [00:00<?, ?B/s]
# A new version of the following files was downloaded from https://huggingface.co/OpenGVLab/InternVL2_5-2B:
# - conversation.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# A new version of the following files was downloaded from https://huggingface.co/OpenGVLab/InternVL2_5-2B:
# - modeling_internvl_chat.py
# - modeling_intern_vit.py
# - modeling_internlm2.py
# - conversation.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# /usr/local/lib/python3.10/dist-packages/timm/models/layers/__init__.py:48: FutureWarning: Importing from timm.models.layers is deprecated, please import via timm.layers
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.layers", FutureWarning)
# FlashAttention2 is not installed.
# model.safetensors:   0%|          | 0.00/4.41G [00:00<?, ?B/s]
# InternLM2ForCausalLM has generative capabilities, as `prepare_inputs_for_generation` is explicitly overwritten. However, it doesn't directly inherit from `GenerationMixin`. From 👉v4.50👈 onwards, `PreTrainedModel` will NOT inherit from `GenerationMixin`, and this model will lose the ability to call `generate` and other related functions.
#   - If you're using `trust_remote_code=True`, you can get rid of this warning by loading the model with an auto class. See https://huggingface.co/docs/transformers/en/model_doc/auto#auto-classes
#   - If you are the owner of the model architecture code, please modify your model class such that it inherits from `GenerationMixin` (after `PreTrainedModel`, otherwise you'll get an exception).
#   - If you are not the owner of the model architecture class, please contact the model code owner to update it.
# Warning: Flash attention is not available, using eager attention instead.
# generation_config.json:   0%|          | 0.00/115 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/4.01k [00:00<?, ?B/s]
# tokenization_internlm2.py:   0%|          | 0.00/8.79k [00:00<?, ?B/s]
# A new version of the following files was downloaded from https://huggingface.co/OpenGVLab/InternVL2_5-2B:
# - tokenization_internlm2.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# tokenizer.model:   0%|          | 0.00/1.48M [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/179 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/844 [00:00<?, ?B/s]

# %%
def process_images_in_batch(image_folder, prompt, model, verbose=True):
  responses = []

  for filename in os.listdir(image_folder):
      if not filename.endswith(('.png', '.jpg', '.jpeg')):
        print("The file must be a valid image file, whose name ending with .png, .jpg, or .jpeg")
        continue

      filepath = os.path.join(image_folder, filename)

      # set the max number of tiles in `max_num`
      pixel_values = load_image(filepath, max_num=12).to(torch.bfloat16).cuda()
      generation_config = dict(max_new_tokens=1024, do_sample=False)

      question = '\n' + prompt
      response = model.chat(tokenizer, pixel_values, question, generation_config)
      responses.append({"image_file":filename,"response": response})

      if verbose == True:
        print(f'Image File: {filename} | Response: {response}')

  return responses


def save_responses(responses, image_folder, csv_file_path, first_write=True, verbose=False):
    ### The file needs to exist if it's not the first write
    if not first_write and not os.path.exists(csv_file_path):
        print("Please provide a valid CSV file path.")
        return

    ### determining original_country and synthesized_race automatically from the folder name
    possible_countries = ['Korea', 'UK', 'Myanmar', 'Azerbaijan']
    possible_synthesized_races = ['Asian', 'Indian', 'Black', 'White', 'Caucasian']

    original_country = [country for country in possible_countries if country in image_folder][0]

    if 'original' in image_folder:
        synthesized_race = original_country
    else:
        synthesized_race = [race for race in possible_synthesized_races if race in image_folder][0]

    ### saving into the csv file
    with open(csv_file_path, mode='a', newline='', encoding='utf-8') as csvfile:
        csv_writer = csv.writer(csvfile)

        # Write the header if it's the first write
        if first_write:
            csv_writer.writerow(['original_country', 'synthesized_race', 'image_file_name', 'response'])

        # Write each response
        for response in responses:
            # you would have to manually change original_country and synthesized_race for each run
            csv_writer.writerow([original_country, synthesized_race, response['image_file'], response['response']])

            if verbose: print(f"Filename: {response['image_file']} | Response: {response['response']}")

        print(f"Data saved to: {csv_file_path}")

    ### sort the rows in the .csv file by file index
    df = pd.read_csv(csv_file_path)
    df["index"] = df["image_file_name"].apply(lambda file_name: int(file_name.split("_")[-1].split(".")[0]))
    df_sorted = df.sort_values(by=["synthesized_race", "index"], ascending=[True, True])
    df_sorted = df_sorted.drop(columns=["index"])
    df_sorted.to_csv(csv_file_path, index=False)

# %%
image_folder = "drive/MyDrive/Team VQA - Datasets/Myanmar_Food/original_images/"
prompt = "Which country is the clothing in the photo mostly associated with? Which visual cues did you use to determine it?"
responses = process_images_in_batch(image_folder, prompt, model)

csv_file_path = "Myanmar_UK_Clothes_Results.csv"
save_responses(responses, image_folder, csv_file_path, first_write=True)
# Out:
# Image File: Myanmar_food_18.png | Response: The clothing in the photo is mostly associated with Malaysia. Here are some visual cues that led to this determination:
#
# 1. **Language and Text**: The text on the shirt reads "Malaysia," which is a clear indicator of the country of origin.
#
# 2. **Cultural Elements**: The style of the shirt, particularly the round glasses and the black color, are often associated with Malaysian fashion.
#
# 3. **Design and Patterns**: The shirt features a design that is commonly seen in Malaysian fashion, which often includes bold patterns and colors.
#
# These elements combined strongly suggest that the clothing is associated with Malaysia.
# Image File: Myanmar_food_15.png | Response: The clothing in the photo appears to be associated with Vietnam. Here are some visual cues that led to this conclusion:
#
# 1. **Color Scheme**: The clothing features a mix of earthy tones, such as browns and beiges, which are common in traditional Vietnamese attire. The pattern and style of the clothing also resemble traditional Vietnamese textiles.
#
# 2. **Design Elements**: The clothing has a distinctly traditional Vietnamese design, with elements like the woven fabric and the style of the sleeves. This is typical of traditional Vietnamese garments.
#
# 3. **Cultural Context**: The setting appears to be a street food market, which is a common environment in Vietnamese culture. Street food vendors often serve traditional Vietnamese dishes, which are known for their rich flavors and use of fresh ingredients.
#
# 4. **Umbrella**: The presence of a traditional Vietnamese umbrella (called a "nón lá") in the background further supports the cultural context of the image.
#
# By considering these visual cues, it is reasonable to deduce that the clothing in the photo is associated with Vietnam.
# Image File: Myanmar_food_17.png | Response: The clothing in the photo appears to be associated with Malaysia. Here are some visual cues that led to this conclusion:
#
# 1. **Text on the Shirt**: The shirt has the word "Malaysia" printed on it. This is a clear indicator that the clothing is related to the country.
#
# 2. **Design and Style**: The design of the shirt, including the font and style, has a distinctly Malaysian aesthetic. The font and color scheme are characteristic of Malaysian fashion.
#
# 3. **Cultural Elements**: The shirt's design includes elements that are commonly found in Malaysian fashion, such as specific patterns or motifs that are popular in the country.
#
# By combining these observations, it is reasonable to conclude that the clothing in the photo is mostly associated with Malaysia.
# Image File: Myanmar_food_13.png | Response: The clothing in the photo appears to be associated with Southeast Asia, particularly China. Here are some visual cues that led to this conclusion:
#
# 1. **Color Scheme**: The clothing in the image features bright and bold colors, which are common in traditional Chinese attire. The purple shirt, for example, is a popular color in Chinese fashion.
#
# 2. **Style of the Shirt**: The shirt worn by the person in the foreground has a loose fit and a casual design, which is typical of traditional Chinese clothing. The style is often seen in everyday wear in China.
#
# 3. **Headwear**: The person in the background is wearing a white cap, which is a common accessory in many parts of China, especially for sun protection and to keep hair out of the face.
#
# 4. **Background Setting**: The setting appears to be a street food market, which is a common environment in many cities in China. The presence of street vendors and the casual, bustling atmosphere aligns with the typical scene in urban Chinese areas.
#
# 5. **Cultural Elements**: The clothing also includes elements like the Chinese characters on the shirt, which are not typically displayed in Western clothing.
#
# By analyzing these visual cues, it is reasonable to deduce that the clothing in the photo is mostly associated with China.
# Image File: Myanmar_food_11.png | Response: The clothing in the photo is mostly associated with Malaysia. The visual cues that led to this determination are the blue headscarves and blue clothing worn by the people in the background, which are commonly associated with Malaysian attire.
# Image File: Myanmar_food_14.png | Response: The clothing in the photo appears to be associated with Vietnam. Here are some visual cues that led to this conclusion:
#
# 1. **Color and Pattern**: The shirt worn by the person in the image has a dark, possibly black, color with a subtle pattern. This style of clothing is commonly seen in Vietnamese fashion, which often features dark colors and simple, functional designs.
#
# 2. **Cultural Context**: Vietnamese clothing often includes elements such as the high collar and the loose fit, which are visible in the shirt worn by the person in the image. These styles are typical in traditional Vietnamese attire.
#
# 3. **Setting**: The setting appears to be an outdoor food market or street food area, which is a common environment in Vietnam. The presence of various dishes and the casual, everyday setting align with Vietnamese street food culture.
#
# 4. **Cuisine**: The type of food being served, which appears to be a noodle dish, is a staple in Vietnamese cuisine. The style of the bowl and the way the food is presented are consistent with Vietnamese street food vendors.
#
# By considering these visual cues, it is reasonable to deduce that the clothing in the photo is associated with Vietnam.
# Image File: Myanmar_food_16.png | Response: The clothing in the photo appears to be associated with South Korea. Here are some visual cues that led to this conclusion:
#
# 1. **Color Scheme**: The green shirt worn by the person in the image is reminiscent of traditional Korean hanbok, which often features green as a prominent color. The green shirt is simple yet elegant, a common style in Korean fashion.
#
# 2. **Style of the Shirt**: The shirt has a clean and minimalistic design, which is typical of Korean fashion. The shirt has a collar and buttons, which are common features in Korean clothing.
#
# 3. **Hair**: The person's hair is styled in a way that is common in Korean fashion, with bangs and a straight, sleek look. This is often seen in traditional Korean hairstyles.
#
# 4. **Background**: The background of the image, which includes modern kitchen elements, suggests a contemporary setting. However, the focus remains on the person and the plate of food, which is a common theme in Korean food culture, where food is often the centerpiece of social gatherings.
#
# 5. **Cultural Context**: The plate of food, which includes ingredients like kimchi and other Korean dishes, aligns with Korean culinary traditions. The presentation of food is an important aspect of Korean culture, often seen in social settings like gatherings or meals.
#
# By considering these visual cues, it is reasonable to deduce that the clothing in the photo is mostly associated with South Korea.
# Image File: Myanmar_food_9.png | Response: The clothing in the photo is mostly associated with Indonesia. Here are the visual cues that led to this determination:
#
# 1. **Language and Cultural References**: The man is wearing a shirt with the word "Pab" on it, which is a common brand name in Indonesia. The woman is wearing a pink shirt, which is a common color choice in Indonesian fashion.
#
# 2. **Design and Style**: The man's black shirt has a sporty design, which is typical of casual wear in Indonesia. The woman's pink shirt is also a popular color in Indonesian fashion, often worn for both casual and semi-formal occasions.
#
# 3. **Cultural Context**: The setting appears to be a home, and the food on the table is typical of Indonesian cuisine. Indonesian meals often include rice, vegetables, and various side dishes, which are visible in the image.
#
# 4. **Brand Recognition**: The presence of a well-known Indonesian brand like "Pab" on the man's shirt is a strong indicator, as it is a brand that is widely recognized in Indonesia.
#
# By considering these elements, it is reasonable to conclude that the clothing in the photo is mostly associated with Indonesia.
# Image File: Myanmar_food_20.png | Response: The clothing in the photo is mostly associated with Malaysia. Here are the visual cues that led to this determination:
#
# 1. **Language and Dialect**: The person is speaking in Malay, which is the official language of Malaysia. The use of Malay words and phrases is a strong indicator of the country's cultural identity.
#
# 2. **Cuisine**: The food being prepared is a popular Malaysian dish, Nasi Lemak. This dish is a staple in Malaysian cuisine and is known for its coconut milk-based broth, which is a significant part of Malaysian culinary culture.
#
# 3. **Cultural Elements**: The person's hairstyle, which is short and styled in a way that is common in Malaysian culture, also supports this identification.
#
# 4. **Color Scheme**: The color scheme of the clothing, particularly the light blue shirt, is reminiscent of traditional Malaysian attire. Malaysian clothing often features bright colors and simple designs.
#
# 5. **Setting**: The background of the photo, which includes elements like the red and black wall and the style of the door, are consistent with the architectural and cultural styles found in Malaysia.
#
# By combining these observations, it is clear that the clothing in the photo is mostly associated with Malaysia.
# Image File: Myanmar_food_8.png | Response: The clothing in the photo is mostly associated with Japan. I determined this by noting the distinctive yellow color with small black dots, which is a common style seen in Japanese fashion.
# Image File: Myanmar_food_12.png | Response: The clothing in the photo is mostly associated with Southeast Asia, particularly Thailand. Here are the visual cues that led to this determination:
#
# 1. **Cultural Patterns**: The clothing features traditional patterns and styles common in Southeast Asian cultures, such as the red and white checkered shirt and the pink shirt with a checkered pattern. These patterns are often seen in Thai and other Southeast Asian textiles.
#
# 2. **Language and Dialect**: The presence of the word "Khop" in the context of the food being prepared suggests a Thai dialect. "Khop" is a common term in Thailand, used to refer to street food vendors or food stalls.
#
# 3. **Street Food Setting**: The setting of the photo, with a small round table and a variety of skewered meats and vegetables, is typical of street food stalls found in Thailand. These stalls are a common sight in urban areas and tourist destinations.
#
# 4. **Urban Environment**: The surrounding environment, with its worn brick walls and utilitarian design, is consistent with the architecture found in many cities in Southeast Asia, particularly in Thailand.
#
# 5. **Cultural Practices**: The casual and communal dining style, with people sitting around a small table and enjoying a meal together, is characteristic of Southeast Asian social customs, particularly in Thailand.
#
# By combining these observations, it is reasonable to conclude that the clothing in the photo is mostly associated with Southeast Asia, particularly Thailand.
# Image File: Myanmar_food_5.png | Response: The clothing in the photo is mostly associated with China. Here are some visual cues that led to this determination:
#
# 1. **Language and Characters**: The text on the clothing is in Chinese characters. This is a strong indicator that the clothing is from China.
#
# 2. **Design and Style**: The clothing style, particularly the long-sleeved shirt, is typical of traditional Chinese fashion. The design elements, such as the cut and fit, also align with common styles seen in Chinese garments.
#
# 3. **Cultural Symbols**: The presence of traditional Chinese symbols or patterns on the clothing can also be a clue. However, in this image, these are not clearly visible.
#
# 4. **Cultural Context**: The overall aesthetic and design of the clothing, including the color and fabric, are consistent with traditional Chinese clothing, which often features intricate patterns and designs.
#
# By combining these observations, it is reasonable to conclude that the clothing in the photo is mostly from China.
# Image File: Myanmar_food_3.png | Response: The clothing in the photo appears to be associated with Southeast Asia, particularly Vietnam. Here are some visual cues that led to this conclusion:
#
# 1. **Pattern and Style**: The black shirt with blue and white patterns is reminiscent of traditional Vietnamese clothing, known as "Tết áo" or "Tet shirt." These shirts are often worn during the Lunar New Year celebrations in Vietnam.
#
# 2. **Text and Design**: The shirt features a design that is common in Vietnamese textiles, which often include intricate patterns and motifs.
#
# 3. **Cultural Context**: The overall aesthetic of the shirt, including the style of the collar and the pattern, aligns with traditional Vietnamese clothing styles.
#
# These elements combined suggest that the clothing is most likely associated with Vietnam.
# Image File: Myanmar_food_1.png | Response: The clothing in the photo is mostly associated with Thailand. Here are some visual cues that led to this determination:
#
# 1. **Language on the Shirt**: The shirt has the Thai script "ไทย" on it. This is a common script used in Thailand.
#
# 2. **Cultural Elements**: The dishes on the table, such as Pad Thai and various Thai curries, are typical of Thai cuisine.
#
# 3. **Cultural Background**: The setting appears to be outdoors, possibly in a Thai cultural or historical site, which aligns with typical Thai outdoor dining experiences.
#
# 4. **Brand Name**: The visible brand name "Rennie" is associated with Thai products, further supporting the connection to Thailand.
#
# These elements combined strongly indicate that the clothing is associated with Thailand.
# Image File: Myanmar_food_2.png | Response: The clothing in the photo is mostly associated with France. The visual cues that led to this determination are:
#
# 1. **Language**: The word "PARIS" is prominently displayed on the glass, which is a clear indicator of the country associated with the clothing.
# 2. **Design**: The style of the clothing, particularly the maroon top, has a distinct French design aesthetic, which is often characterized by such bold colors and patterns.
#
# These elements combined strongly suggest that the clothing is associated with France.
# Image File: Myanmar_food_4.png | Response: The clothing in the photo is mostly associated with Indonesia. Here are some visual cues that led to this conclusion:
#
# 1. **Language on the Clothing**: The text on the clothing appears to be in Indonesian. This is a strong indicator, as Indonesian is the official language of Indonesia.
#
# 2. **Design and Style**: The clothing style, particularly the red shirt worn by the person, has a traditional and cultural design that is common in Indonesian attire. Indonesian clothing often features vibrant colors and traditional patterns.
#
# 3. **Cultural Context**: The setting of the image, which includes a table with various Indonesian dishes, suggests a cultural context that is likely related to Indonesian cuisine. Indonesian food often includes dishes like nasi goreng, gado-gado, and sate, which are prominently featured in the image.
#
# 4. **Cans with Branding**: The cans in the image have branding that is consistent with Indonesian products. The branding and packaging are distinct and recognizable, further supporting the association with Indonesia.
#
# By combining these observations, it is reasonable to conclude that the clothing in the photo is mostly associated with Indonesia.
# Image File: Myanmar_food_6.png | Response: The clothing in the photo is mostly associated with Vietnam. The visual cues that led to this determination include the style of the clothing, the use of a hairnet by the woman preparing food, and the overall setting of the scene, which resembles a typical street food market in Vietnam. The clothing styles, such as the floral pattern and the color choices, are commonly seen in Vietnamese street fashion. Additionally, the presence of a hairnet, a common tool used in food preparation in many Southeast Asian countries, particularly in Vietnam, further supports this association.
# Image File: Myanmar_food_7.png | Response: The clothing in the photo is mostly associated with Vietnam. I determined this based on the visual cues such as the style of the blue shirt, the red hair accessory, and the overall appearance of the clothing, which align with common styles seen in Vietnam.
# Image File: Myanmar_food_10.png | Response: The clothing in the photo is mostly associated with China. The visual cues include the style of clothing, such as the black shirt with a cartoon character and the white shirt with a colorful design, which are commonly seen in Chinese fashion.
# Image File: Myanmar_food_19.png | Response: The clothing in the photo is mostly associated with Japan. The visual cues that led to this determination include the style of the cap, which resembles a traditional Japanese cap known as a "hanabata," and the overall aesthetic of the clothing, which has a minimalist and modern look that is commonly seen in Japanese fashion. Additionally, the black color scheme and the simplicity of the design are also characteristic of Japanese fashion trends.
# Data saved to: Myanmar_UK_Clothes_Results.csv

# %% [markdown]
# ### Individual Processing

# %%
# set the max number of tiles in `max_num`
pixel_values = load_image('Myanmar_food_3.png', max_num=12).to(torch.bfloat16).cuda()
generation_config = dict(max_new_tokens=1024, do_sample=False)


# single-image multi-round conversation (单图多轮对话)
question = '\nPlease describe the image in detail.'
response = model.chat(tokenizer, pixel_values, question, generation_config)
print(f'User: {question}\nAssistant: {response}')
# Out:
# User:
# Please describe the image in detail.
# Assistant: The image shows a person sitting at a table with a plate of food in front of them. The person is wearing a black shirt with a blue and white leaf pattern. They are holding a fork and appear to be about to eat a dish that includes noodles, possibly with a curry or sauce, garnished with green herbs.
#
# On the table, there is a large bowl of a light brown liquid, likely a soup or broth. In front of the plate, there is a small bowl of a reddish-brown sauce, possibly a spicy condiment. There is also a plate with a portion of white noodles, and some fresh green herbs, possibly cilantro, are visible. The background is a pink brick wall.
